# %%
from funrec.features.feature_column import FeatureColumn

print("import ok")
# Out:
# E:\推荐系统\项目\阿里天池\funrec\utils.py:34: UserWarning: 未找到 .env 文件。使用默认路径作为回退。建议创建 .env 文件并设置 FUNREC_RAW_DATA_PATH 和 FUNREC_PROCESSED_DATA_PATH。或者使用默认路径: data（输入数据）和 tmp（处理后的数据）
#   warnings.warn(
# E:\推荐系统\项目\阿里天池\funrec\utils.py:45: UserWarning: 使用默认 RAW_DATA_PATH: E:\推荐系统\项目\阿里天池\data
#   warnings.warn(f"使用默认 RAW_DATA_PATH: {default_raw_path}")
# E:\推荐系统\项目\阿里天池\funrec\utils.py:50: UserWarning: 使用默认 PROCESSED_DATA_PATH: E:\推荐系统\项目\阿里天池\tmp
#   warnings.warn(f"使用默认 PROCESSED_DATA_PATH: {default_processed_path}")
# import ok

# %%
import os
print(os.getcwd())
# Out:
# E:\推荐系统\项目\阿里天池
