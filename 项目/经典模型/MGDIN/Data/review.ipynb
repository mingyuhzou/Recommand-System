# %%
import polars as pl

# %%
df = pl.read_ndjson("../Sports/Sports_and_Outdoors_5.json")

df.head()
# Out:
# shape: (5, 11)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ overall ┆ vote ┆ verified ┆ reviewTime  ┆ … ┆ reviewerNam ┆ reviewText ┆ summary    ┆ unixReview │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ e           ┆ ---        ┆ ---        ┆ Time       │
# │ f64     ┆ str  ┆ bool     ┆ str         ┆   ┆ ---         ┆ str        ┆ str        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆ str         ┆            ┆            ┆ i64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 5.0     ┆ null ┆ true     ┆ 06 3, 2015  ┆ … ┆ Michelle A  ┆ What a spe ┆ Five Stars ┆ 1433289600 │
# │         ┆      ┆          ┆             ┆   ┆             ┆ ctacular   ┆            ┆            │
# │         ┆      ┆          ┆             ┆   ┆             ┆ tutu! Very ┆            ┆            │
# ...

# %%
df.columns
# Out:
# ['overall',
#  'vote',
#  'verified',
#  'reviewTime',
#  'reviewerID',
#  'asin',
#  'style',
#  'reviewerName',
#  'reviewText',
#  'summary',
#  'unixReviewTime']
