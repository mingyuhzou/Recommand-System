# %%
import polars as pl
from config import cfg

# %%
data=pl.read_parquet(cfg['train'])

# %%
data.head()
# Out:
# shape: (5, 6)
# ┌────────┬──────────┬────────────────────┬─────────────────────┬───────────────────────────┬───────┐
# │ userId ┆ movie_id ┆ movie_cate_id_list ┆ rated_movie_id_list ┆ rated_movie_cate_id_list  ┆ label │
# │ ---    ┆ ---      ┆ ---                ┆ ---                 ┆ ---                       ┆ ---   │
# │ i64    ┆ i64      ┆ list[i64]          ┆ list[i64]           ┆ list[list[i64]]           ┆ i32   │
# ╞════════╪══════════╪════════════════════╪═════════════════════╪═══════════════════════════╪═══════╡
# │ 58920  ┆ 145      ┆ [2, 6, … 18]       ┆ [1270, 364, … 2671] ┆ [[3, 6, 17], [3, 4, …     ┆ 0     │
# │        ┆          ┆                    ┆                     ┆ 14], … […                 ┆       │
# │ 58920  ┆ 2470     ┆ [3, 6]             ┆ [364, 858, … 145]   ┆ [[3, 4, … 14], [7, 9], …  ┆ 0     │
# │        ┆          ┆                    ┆                     ┆ [2, 6…                    ┆       │
# ...

# %%
data.columns
# Out:
# ['userId',
#  'movie_id',
#  'movie_cate_id_list',
#  'rated_movie_id_list',
#  'rated_movie_cate_id_list',
#  'label']

# %%
data.shape
# Out:
# (14443552, 6)

# %%
data['userId'].n_unique()
# Out:
# 100000

# %%
min(data['userId'])
# Out:
# 2

# %%
min(data['movie_id'])
# Out:
# 1

# %%
max(data['movie_id'])
# Out:
# 131262
